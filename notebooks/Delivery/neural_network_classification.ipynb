# %%
import numpy as np
import torch
import pandas as pd
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, classification_report
from sklearn.utils.class_weight import compute_class_weight
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../../data/interim/olist_ml_processed_dataset.csv')

status_mapping = {
    'Very Early': 0,
    'Somewhat Early': 1,
    'Early': 2,
    'On Time': 3,
    'Somewhat Late': 4,
    'Very Late': 5
}

# %%
X_raw = df.drop(columns=['actual_delivery_days', 'delivery_status', 'delivery_label']).values
y_raw = df['delivery_label'].values

X_train, X_test, y_train, y_test = train_test_split(
    X_raw, y_raw, test_size=0.2, random_state=42, stratify=y_raw
)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


# Features go to float32; labels go to long (integers) for CrossEntropyLoss
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)

X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)

# --- Step 4: Create DataLoaders ---
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

BATCH_SIZE = 256  # Adjust this depending on your preferences

train_loader = DataLoader(
    dataset=train_dataset, 
    batch_size=BATCH_SIZE, 
    shuffle=True          # Shuffle training data to help generalization
)

test_loader = DataLoader(
    dataset=test_dataset, 
    batch_size=BATCH_SIZE, 
    shuffle=False          # No need to shuffle test/evaluation data
)

print(f"DataLoaders successfully created!")
print(f"Train batches: {len(train_loader)} | Test batches: {len(test_loader)}")
# Out:
# DataLoaders successfully created!
# Train batches: 271 | Test batches: 68

# %%
class RegularizedDeepClassifier(nn.Module):
    def __init__(self, input_dim, dropout_rate=0.2):
        super(RegularizedDeepClassifier, self).__init__()
        
        # Define the 5 Hidden Layers
        self.fc1 = nn.Linear(input_dim, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 128)
        self.fc4 = nn.Linear(128, 64)
        self.fc5 = nn.Linear(64, 32)
        self.fc6 = nn.Linear(32, 16)
        self.out = nn.Linear(16, 6)
        
        # Activations and Regularization
        self.gelu = nn.GELU()
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(p=dropout_rate)
        
        # Apply Xavier Initialization immediately to all linear layers
        self._init_weights()
        
    def _init_weights(self):
        # Loop through all layers of the model
        for name, module in self.named_modules():
            if isinstance(module, nn.Linear):
                # FIXED: Changed from xavier_uniform_ to kaiming_uniform_
                # nonlinearity='relu' is the correct mathematical proxy for GELU here
                nn.init.kaiming_uniform_(module.weight, nonlinearity='relu')
                
                # Initialize biases to 0
                if module.bias is not None:
                    nn.init.constant_(module.bias, 0.0)
        
    def forward(self, x):
        # Layer 1
        x = self.gelu(self.fc1(x))
        x = self.dropout(x)
        
        # Layer 2
        x = self.gelu(self.fc2(x))
        x = self.dropout(x)
        
        # Layer 3
        x = self.gelu(self.fc3(x))
        x = self.dropout(x)
        
        # Layer 4
        x = self.gelu(self.fc4(x))
        x = self.dropout(x)
        
        # Layer 5
        x = self.gelu(self.fc5(x))
        x = self.dropout(x)
        # Layer 6
        x = self.gelu(self.fc6(x))
        x = self.dropout(x)
        

        x = self.out(x)
        return x

# --- Initialization ---
classes = np.unique(y_train)
class_weights = compute_class_weight(
    class_weight='balanced', 
    classes=classes, 
    y=y_train
)
class_weights_tensor = torch.FloatTensor(class_weights).to(device)

input_features = X_train_tensor.shape[1]

# Instantiate your model (Dropout defaults to 0.2, adjust if needed)
model = RegularizedDeepClassifier(input_dim=input_features, dropout_rate=0.2)

# Loss and Optimizer remain setup for the updated architecture  
criterion_cls = nn.CrossEntropyLoss(weight=class_weights_tensor, label_smoothing=0.1)
criterion_reg = nn.HuberLoss(delta=1.0)
optimizer = optim.AdamW(model.parameters(), lr=0.01, weight_decay=1e-3)
scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3)

print(model)
# Out:
# RegularizedDeepClassifier(
#   (fc1): Linear(in_features=7, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=128, bias=True)
#   (fc3): Linear(in_features=128, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=64, bias=True)
#   (fc5): Linear(in_features=64, out_features=32, bias=True)
#   (fc6): Linear(in_features=32, out_features=16, bias=True)
#   (out): Linear(in_features=16, out_features=6, bias=True)
#   (gelu): GELU(approximate='none')
#   (relu): ReLU()
#   (dropout): Dropout(p=0.2, inplace=False)
# )

# %%
    # Ensure device matches your infrastructure setup
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

epochs = 75
history = {
    'train_loss': [], 'test_loss': [],
    'train_huber_loss': [], 'test_huber_loss': [],
    'train_acc': [], 'test_acc': [],
    'train_precision': [], 'test_precision': [],
    'train_recall': [], 'test_recall': [],
    'train_f1': [], 'test_f1': []
}

for epoch in range(epochs):
    # ================= TRAINING PHASE =================
    model.train()
    running_train_loss = 0.0
    running_train_huber = 0.0
    all_train_preds = []
    all_train_trues = []
    
    for batch_X, batch_y in train_loader:
        batch_X, batch_y = batch_X.to(device), batch_y.to(device)
        
        optimizer.zero_grad()
        outputs = model(batch_X)
        
        loss = criterion_cls(outputs, batch_y)
        loss_huber = criterion_reg(outputs[:, 0], batch_y.float()) 
        loss.backward()
        optimizer.step()
        
        running_train_loss += loss.item() * batch_X.size(0)
        running_train_huber += loss_huber.item() * batch_X.size(0)
        
        _, preds = torch.max(outputs, 1)
        all_train_preds.extend(preds.cpu().numpy())
        all_train_trues.extend(batch_y.cpu().numpy())
        
    epoch_train_loss = running_train_loss / len(train_dataset)
    epoch_train_huber = running_train_huber / len(train_dataset)
    epoch_train_acc = accuracy_score(all_train_trues, all_train_preds)
    
    # Calculate Macro metrics for training
    train_prec, train_rec, train_f1, _ = precision_recall_fscore_support(
        all_train_trues, all_train_preds, average='macro', zero_division=0
    )
    
    # ================= TESTING PHASE =================
    model.eval()
    running_test_loss = 0.0
    running_test_huber = 0.0
    all_test_preds = []
    all_test_trues = []
    
    with torch.no_grad():
        for batch_X, batch_y in test_loader:
            batch_X, batch_y = batch_X.to(device), batch_y.to(device)
            
            outputs = model(batch_X)
            loss = criterion_cls(outputs, batch_y)
            
            running_test_loss += loss.item() * batch_X.size(0)

            # Track Test Huber Loss
            loss_huber = criterion_reg(outputs[:, 0], batch_y.float())
            running_test_huber += loss_huber.item() * batch_X.size(0)   
            
            _, preds = torch.max(outputs, 1)    
            all_test_preds.extend(preds.cpu().numpy())
            all_test_trues.extend(batch_y.cpu().numpy())
            
    epoch_test_loss = running_test_loss / len(test_dataset)
    epoch_test_huber = running_test_huber / len(test_dataset)   
    epoch_test_acc = accuracy_score(all_test_trues, all_test_preds)
    
    # Calculate Macro metrics for validation
    test_prec, test_rec, test_f1, _ = precision_recall_fscore_support(
        all_test_trues, all_test_preds, average='macro', zero_division=0
    )
    scheduler.step(epoch_test_loss)
    
    # ================= STORE METRICS =================
    history['train_loss'].append(epoch_train_loss)
    history['test_loss'].append(epoch_test_loss)
    history['train_huber_loss'].append(epoch_train_huber)
    history['test_huber_loss'].append(epoch_test_huber)
    history['train_acc'].append(epoch_train_acc)
    history['test_acc'].append(epoch_test_acc)
    history['train_precision'].append(train_prec)
    history['test_precision'].append(test_prec)
    history['train_recall'].append(train_recall := train_rec) # syntactic assignment
    history['test_recall'].append(test_rec)
    history['train_f1'].append(train_f1)
    history['test_f1'].append(test_f1)
    
    current_lr = optimizer.param_groups[0]['lr']

    # Detailed log print per epoch
    print(f"Epoch {epoch+1:02d}/{epochs} | "
          f"Train Loss: {epoch_train_loss:.4f} - Test Loss: {epoch_test_loss:.4f} | "
          f"Train Huber Loss: {epoch_train_huber:.4f} - Test Huber Loss: {epoch_test_huber:.4f} | "
          f"Test Acc: {epoch_test_acc*100:.1f}% - Test Macro F1: {test_f1*100:.1f}% |"
          f"LR: {current_lr:.6f}")

# Print the complete per-class breakdown at completion
print("\nFinal Performance Breakdown:")
print(classification_report(all_test_trues, all_test_preds, target_names=list(status_mapping.keys()), zero_division=0))
# Out:
# Epoch 01/75 | Train Loss: 1.6804 - Test Loss: 1.5742 | Train Huber Loss: 2.0949 - Test Huber Loss: 2.2167 | Test Acc: 32.1% - Test Macro F1: 31.7% |LR: 0.010000
# Epoch 02/75 | Train Loss: 1.5956 - Test Loss: 1.5480 | Train Huber Loss: 2.2624 - Test Huber Loss: 2.2808 | Test Acc: 34.4% - Test Macro F1: 34.0% |LR: 0.010000
# Epoch 03/75 | Train Loss: 1.5839 - Test Loss: 1.5568 | Train Huber Loss: 2.2832 - Test Huber Loss: 2.3463 | Test Acc: 35.3% - Test Macro F1: 36.2% |LR: 0.010000
# Epoch 04/75 | Train Loss: 1.5782 - Test Loss: 1.5401 | Train Huber Loss: 2.2870 - Test Huber Loss: 2.4405 | Test Acc: 34.2% - Test Macro F1: 32.9% |LR: 0.010000
# Epoch 05/75 | Train Loss: 1.5717 - Test Loss: 1.5517 | Train Huber Loss: 2.3022 - Test Huber Loss: 2.3879 | Test Acc: 36.0% - Test Macro F1: 36.9% |LR: 0.010000
# Epoch 06/75 | Train Loss: 1.5707 - Test Loss: 1.5410 | Train Huber Loss: 2.3057 - Test Huber Loss: 2.3689 | Test Acc: 34.2% - Test Macro F1: 34.3% |LR: 0.010000
# Epoch 07/75 | Train Loss: 1.5650 - Test Loss: 1.5382 | Train Huber Loss: 2.3076 - Test Huber Loss: 2.3524 | Test Acc: 35.7% - Test Macro F1: 36.5% |LR: 0.010000
# Epoch 08/75 | Train Loss: 1.5670 - Test Loss: 1.5398 | Train Huber Loss: 2.2881 - Test Huber Loss: 2.3179 | Test Acc: 35.7% - Test Macro F1: 36.0% |LR: 0.010000
# Epoch 09/75 | Train Loss: 1.5702 - Test Loss: 1.5369 | Train Huber Loss: 2.2514 - Test Huber Loss: 2.3182 | Test Acc: 34.3% - Test Macro F1: 33.6% |LR: 0.010000
# Epoch 10/75 | Train Loss: 1.5674 - Test Loss: 1.5423 | Train Huber Loss: 2.2570 - Test Huber Loss: 2.2586 | Test Acc: 33.6% - Test Macro F1: 33.3% |LR: 0.010000
# Epoch 11/75 | Train Loss: 1.5679 - Test Loss: 1.5387 | Train Huber Loss: 2.2692 - Test Huber Loss: 2.3190 | Test Acc: 35.2% - Test Macro F1: 34.4% |LR: 0.010000
# Epoch 12/75 | Train Loss: 1.5711 - Test Loss: 1.5541 | Train Huber Loss: 2.2404 - Test Huber Loss: 2.2346 | Test Acc: 35.1% - Test Macro F1: 35.9% |LR: 0.010000
# Epoch 13/75 | Train Loss: 1.5785 - Test Loss: 1.5552 | Train Huber Loss: 2.2128 - Test Huber Loss: 2.2241 | Test Acc: 31.9% - Test Macro F1: 31.3% |LR: 0.005000
# Epoch 14/75 | Train Loss: 1.5658 - Test Loss: 1.5460 | Train Huber Loss: 2.2104 - Test Huber Loss: 2.3139 | Test Acc: 34.7% - Test Macro F1: 35.4% |LR: 0.005000
# Epoch 15/75 | Train Loss: 1.5584 - Test Loss: 1.5307 | Train Huber Loss: 2.2496 - Test Huber Loss: 2.2735 | Test Acc: 35.1% - Test Macro F1: 35.8% |LR: 0.005000
# Epoch 16/75 | Train Loss: 1.5558 - Test Loss: 1.5340 | Train Huber Loss: 2.2655 - Test Huber Loss: 2.3596 | Test Acc: 36.3% - Test Macro F1: 37.8% |LR: 0.005000
# Epoch 17/75 | Train Loss: 1.5540 - Test Loss: 1.5318 | Train Huber Loss: 2.2860 - Test Huber Loss: 2.2885 | Test Acc: 35.7% - Test Macro F1: 36.0% |LR: 0.005000
# Epoch 18/75 | Train Loss: 1.5562 - Test Loss: 1.5416 | Train Huber Loss: 2.2819 - Test Huber Loss: 2.3429 | Test Acc: 36.8% - Test Macro F1: 37.9% |LR: 0.005000
# Epoch 19/75 | Train Loss: 1.5553 - Test Loss: 1.5352 | Train Huber Loss: 2.2702 - Test Huber Loss: 2.3621 | Test Acc: 35.9% - Test Macro F1: 37.1% |LR: 0.002500
# Epoch 20/75 | Train Loss: 1.5494 - Test Loss: 1.5281 | Train Huber Loss: 2.2977 - Test Huber Loss: 2.3348 | Test Acc: 36.1% - Test Macro F1: 37.2% |LR: 0.002500
# Epoch 21/75 | Train Loss: 1.5472 - Test Loss: 1.5303 | Train Huber Loss: 2.2901 - Test Huber Loss: 2.3619 | Test Acc: 36.3% - Test Macro F1: 37.6% |LR: 0.002500
# Epoch 22/75 | Train Loss: 1.5462 - Test Loss: 1.5263 | Train Huber Loss: 2.3080 - Test Huber Loss: 2.3475 | Test Acc: 35.9% - Test Macro F1: 37.1% |LR: 0.002500
# Epoch 23/75 | Train Loss: 1.5458 - Test Loss: 1.5234 | Train Huber Loss: 2.3134 - Test Huber Loss: 2.3395 | Test Acc: 36.1% - Test Macro F1: 36.4% |LR: 0.002500
# Epoch 24/75 | Train Loss: 1.5432 - Test Loss: 1.5251 | Train Huber Loss: 2.3214 - Test Huber Loss: 2.3609 | Test Acc: 36.3% - Test Macro F1: 37.3% |LR: 0.002500
# Epoch 25/75 | Train Loss: 1.5453 - Test Loss: 1.5255 | Train Huber Loss: 2.3258 - Test Huber Loss: 2.3785 | Test Acc: 36.5% - Test Macro F1: 37.2% |LR: 0.002500
# Epoch 26/75 | Train Loss: 1.5436 - Test Loss: 1.5274 | Train Huber Loss: 2.3255 - Test Huber Loss: 2.3658 | Test Acc: 36.5% - Test Macro F1: 37.7% |LR: 0.002500
# Epoch 27/75 | Train Loss: 1.5434 - Test Loss: 1.5203 | Train Huber Loss: 2.3320 - Test Huber Loss: 2.3631 | Test Acc: 36.1% - Test Macro F1: 37.7% |LR: 0.002500
# Epoch 28/75 | Train Loss: 1.5403 - Test Loss: 1.5231 | Train Huber Loss: 2.3268 - Test Huber Loss: 2.3931 | Test Acc: 36.7% - Test Macro F1: 37.2% |LR: 0.002500
# Epoch 29/75 | Train Loss: 1.5418 - Test Loss: 1.5238 | Train Huber Loss: 2.3342 - Test Huber Loss: 2.3880 | Test Acc: 36.4% - Test Macro F1: 37.8% |LR: 0.002500
# Epoch 30/75 | Train Loss: 1.5397 - Test Loss: 1.5219 | Train Huber Loss: 2.3344 - Test Huber Loss: 2.3819 | Test Acc: 36.9% - Test Macro F1: 37.9% |LR: 0.002500
# Epoch 31/75 | Train Loss: 1.5407 - Test Loss: 1.5219 | Train Huber Loss: 2.3371 - Test Huber Loss: 2.3980 | Test Acc: 37.1% - Test Macro F1: 37.9% |LR: 0.001250
# Epoch 32/75 | Train Loss: 1.5371 - Test Loss: 1.5196 | Train Huber Loss: 2.3459 - Test Huber Loss: 2.3743 | Test Acc: 37.1% - Test Macro F1: 38.8% |LR: 0.001250
# Epoch 33/75 | Train Loss: 1.5371 - Test Loss: 1.5170 | Train Huber Loss: 2.3375 - Test Huber Loss: 2.3739 | Test Acc: 37.5% - Test Macro F1: 38.3% |LR: 0.001250
# Epoch 34/75 | Train Loss: 1.5332 - Test Loss: 1.5144 | Train Huber Loss: 2.3413 - Test Huber Loss: 2.3862 | Test Acc: 36.9% - Test Macro F1: 38.0% |LR: 0.001250
# Epoch 35/75 | Train Loss: 1.5335 - Test Loss: 1.5159 | Train Huber Loss: 2.3447 - Test Huber Loss: 2.3683 | Test Acc: 36.6% - Test Macro F1: 37.9% |LR: 0.001250
# Epoch 36/75 | Train Loss: 1.5328 - Test Loss: 1.5177 | Train Huber Loss: 2.3458 - Test Huber Loss: 2.3785 | Test Acc: 37.3% - Test Macro F1: 38.7% |LR: 0.001250
# Epoch 37/75 | Train Loss: 1.5322 - Test Loss: 1.5143 | Train Huber Loss: 2.3562 - Test Huber Loss: 2.3970 | Test Acc: 37.2% - Test Macro F1: 38.0% |LR: 0.001250
# Epoch 38/75 | Train Loss: 1.5327 - Test Loss: 1.5145 | Train Huber Loss: 2.3517 - Test Huber Loss: 2.3998 | Test Acc: 37.4% - Test Macro F1: 38.3% |LR: 0.000625
# Epoch 39/75 | Train Loss: 1.5307 - Test Loss: 1.5130 | Train Huber Loss: 2.3574 - Test Huber Loss: 2.3849 | Test Acc: 37.4% - Test Macro F1: 38.6% |LR: 0.000625
# Epoch 40/75 | Train Loss: 1.5295 - Test Loss: 1.5113 | Train Huber Loss: 2.3567 - Test Huber Loss: 2.3902 | Test Acc: 37.3% - Test Macro F1: 38.4% |LR: 0.000625
# Epoch 41/75 | Train Loss: 1.5292 - Test Loss: 1.5121 | Train Huber Loss: 2.3554 - Test Huber Loss: 2.3942 | Test Acc: 37.5% - Test Macro F1: 38.7% |LR: 0.000625
# Epoch 42/75 | Train Loss: 1.5287 - Test Loss: 1.5099 | Train Huber Loss: 2.3584 - Test Huber Loss: 2.3995 | Test Acc: 37.3% - Test Macro F1: 38.6% |LR: 0.000625
# Epoch 43/75 | Train Loss: 1.5274 - Test Loss: 1.5142 | Train Huber Loss: 2.3633 - Test Huber Loss: 2.4184 | Test Acc: 37.9% - Test Macro F1: 38.9% |LR: 0.000625
# Epoch 44/75 | Train Loss: 1.5277 - Test Loss: 1.5125 | Train Huber Loss: 2.3653 - Test Huber Loss: 2.4034 | Test Acc: 37.5% - Test Macro F1: 38.7% |LR: 0.000625
# Epoch 45/75 | Train Loss: 1.5265 - Test Loss: 1.5099 | Train Huber Loss: 2.3631 - Test Huber Loss: 2.4016 | Test Acc: 37.3% - Test Macro F1: 38.3% |LR: 0.000625
# Epoch 46/75 | Train Loss: 1.5284 - Test Loss: 1.5102 | Train Huber Loss: 2.3646 - Test Huber Loss: 2.4065 | Test Acc: 37.8% - Test Macro F1: 38.9% |LR: 0.000313
# Epoch 47/75 | Train Loss: 1.5269 - Test Loss: 1.5111 | Train Huber Loss: 2.3704 - Test Huber Loss: 2.4066 | Test Acc: 37.7% - Test Macro F1: 39.0% |LR: 0.000313
# Epoch 48/75 | Train Loss: 1.5274 - Test Loss: 1.5110 | Train Huber Loss: 2.3696 - Test Huber Loss: 2.4218 | Test Acc: 37.7% - Test Macro F1: 38.9% |LR: 0.000313
# Epoch 49/75 | Train Loss: 1.5256 - Test Loss: 1.5131 | Train Huber Loss: 2.3745 - Test Huber Loss: 2.4165 | Test Acc: 37.7% - Test Macro F1: 39.0% |LR: 0.000313
# Epoch 50/75 | Train Loss: 1.5260 - Test Loss: 1.5103 | Train Huber Loss: 2.3761 - Test Huber Loss: 2.4088 | Test Acc: 37.5% - Test Macro F1: 38.7% |LR: 0.000156
# Epoch 51/75 | Train Loss: 1.5250 - Test Loss: 1.5087 | Train Huber Loss: 2.3742 - Test Huber Loss: 2.4108 | Test Acc: 37.4% - Test Macro F1: 38.5% |LR: 0.000156
# Epoch 52/75 | Train Loss: 1.5248 - Test Loss: 1.5089 | Train Huber Loss: 2.3711 - Test Huber Loss: 2.4116 | Test Acc: 37.5% - Test Macro F1: 38.7% |LR: 0.000156
# Epoch 53/75 | Train Loss: 1.5242 - Test Loss: 1.5095 | Train Huber Loss: 2.3730 - Test Huber Loss: 2.4151 | Test Acc: 37.6% - Test Macro F1: 38.8% |LR: 0.000156
# Epoch 54/75 | Train Loss: 1.5248 - Test Loss: 1.5093 | Train Huber Loss: 2.3722 - Test Huber Loss: 2.4139 | Test Acc: 37.5% - Test Macro F1: 38.7% |LR: 0.000156
# Epoch 55/75 | Train Loss: 1.5255 - Test Loss: 1.5104 | Train Huber Loss: 2.3734 - Test Huber Loss: 2.4122 | Test Acc: 37.8% - Test Macro F1: 39.0% |LR: 0.000078
# Epoch 56/75 | Train Loss: 1.5241 - Test Loss: 1.5092 | Train Huber Loss: 2.3726 - Test Huber Loss: 2.4093 | Test Acc: 37.7% - Test Macro F1: 39.0% |LR: 0.000078
# Epoch 57/75 | Train Loss: 1.5234 - Test Loss: 1.5088 | Train Huber Loss: 2.3715 - Test Huber Loss: 2.4107 | Test Acc: 37.7% - Test Macro F1: 39.0% |LR: 0.000078
# Epoch 58/75 | Train Loss: 1.5233 - Test Loss: 1.5095 | Train Huber Loss: 2.3724 - Test Huber Loss: 2.4129 | Test Acc: 37.8% - Test Macro F1: 39.0% |LR: 0.000078
# Epoch 59/75 | Train Loss: 1.5231 - Test Loss: 1.5084 | Train Huber Loss: 2.3726 - Test Huber Loss: 2.4094 | Test Acc: 37.7% - Test Macro F1: 38.8% |LR: 0.000078
# Epoch 60/75 | Train Loss: 1.5263 - Test Loss: 1.5087 | Train Huber Loss: 2.3719 - Test Huber Loss: 2.4106 | Test Acc: 37.7% - Test Macro F1: 38.9% |LR: 0.000078
# Epoch 61/75 | Train Loss: 1.5245 - Test Loss: 1.5091 | Train Huber Loss: 2.3703 - Test Huber Loss: 2.4110 | Test Acc: 37.7% - Test Macro F1: 38.9% |LR: 0.000078
# Epoch 62/75 | Train Loss: 1.5240 - Test Loss: 1.5079 | Train Huber Loss: 2.3719 - Test Huber Loss: 2.4065 | Test Acc: 37.6% - Test Macro F1: 38.7% |LR: 0.000078
# Epoch 63/75 | Train Loss: 1.5235 - Test Loss: 1.5085 | Train Huber Loss: 2.3715 - Test Huber Loss: 2.4080 | Test Acc: 37.6% - Test Macro F1: 38.8% |LR: 0.000078
# Epoch 64/75 | Train Loss: 1.5240 - Test Loss: 1.5087 | Train Huber Loss: 2.3697 - Test Huber Loss: 2.4074 | Test Acc: 37.6% - Test Macro F1: 38.9% |LR: 0.000078
# Epoch 65/75 | Train Loss: 1.5240 - Test Loss: 1.5084 | Train Huber Loss: 2.3717 - Test Huber Loss: 2.4080 | Test Acc: 37.6% - Test Macro F1: 38.8% |LR: 0.000078
# Epoch 66/75 | Train Loss: 1.5242 - Test Loss: 1.5086 | Train Huber Loss: 2.3719 - Test Huber Loss: 2.4081 | Test Acc: 37.6% - Test Macro F1: 38.8% |LR: 0.000039
# Epoch 67/75 | Train Loss: 1.5240 - Test Loss: 1.5091 | Train Huber Loss: 2.3687 - Test Huber Loss: 2.4092 | Test Acc: 37.8% - Test Macro F1: 39.0% |LR: 0.000039
# Epoch 68/75 | Train Loss: 1.5217 - Test Loss: 1.5088 | Train Huber Loss: 2.3691 - Test Huber Loss: 2.4091 | Test Acc: 37.7% - Test Macro F1: 38.9% |LR: 0.000039
# Epoch 69/75 | Train Loss: 1.5237 - Test Loss: 1.5085 | Train Huber Loss: 2.3712 - Test Huber Loss: 2.4096 | Test Acc: 37.7% - Test Macro F1: 38.8% |LR: 0.000039
# Epoch 70/75 | Train Loss: 1.5242 - Test Loss: 1.5084 | Train Huber Loss: 2.3729 - Test Huber Loss: 2.4076 | Test Acc: 37.7% - Test Macro F1: 38.9% |LR: 0.000020
# Epoch 71/75 | Train Loss: 1.5238 - Test Loss: 1.5085 | Train Huber Loss: 2.3714 - Test Huber Loss: 2.4083 | Test Acc: 37.7% - Test Macro F1: 38.9% |LR: 0.000020
# Epoch 72/75 | Train Loss: 1.5245 - Test Loss: 1.5084 | Train Huber Loss: 2.3695 - Test Huber Loss: 2.4092 | Test Acc: 37.6% - Test Macro F1: 38.8% |LR: 0.000020
# Epoch 73/75 | Train Loss: 1.5239 - Test Loss: 1.5085 | Train Huber Loss: 2.3732 - Test Huber Loss: 2.4102 | Test Acc: 37.7% - Test Macro F1: 38.8% |LR: 0.000020
# Epoch 74/75 | Train Loss: 1.5226 - Test Loss: 1.5083 | Train Huber Loss: 2.3729 - Test Huber Loss: 2.4092 | Test Acc: 37.6% - Test Macro F1: 38.8% |LR: 0.000010
# Epoch 75/75 | Train Loss: 1.5230 - Test Loss: 1.5083 | Train Huber Loss: 2.3716 - Test Huber Loss: 2.4093 | Test Acc: 37.6% - Test Macro F1: 38.8% |LR: 0.000010
#
# Final Performance Breakdown:
#                 precision    recall  f1-score   support
#
#     Very Early       0.38      0.75      0.51      1805
# Somewhat Early       0.36      0.13      0.19      3503
#          Early       0.34      0.41      0.37      3920
#        On Time       0.41      0.30      0.35      4410
#  Somewhat Late       0.33      0.44      0.38      2449
#      Very Late       0.51      0.56      0.53      1219
#
#       accuracy                           0.38     17306
#      macro avg       0.39      0.43      0.39     17306
#   weighted avg       0.38      0.38      0.36     17306

# %%
# ================= VISUALIZATION (2x3 Grid) =================
fig, axs = plt.subplots(2, 3, figsize=(14, 8))

# 1. Cross-Entropy Loss Curve
axs[0, 0].plot(range(1, epochs + 1), history['train_loss'], label='Train Loss')
axs[0, 0].plot(range(1, epochs + 1), history['test_loss'], label='Test Loss')
axs[0, 0].set_title('Cross-Entropy Loss Curve')
axs[0, 0].set_xlabel('Epochs')
axs[0, 0].set_ylabel('Loss')
axs[0, 0].legend()
axs[0, 0].grid(True)

# 2. Global Accuracy Curve
axs[0, 1].plot(range(1, epochs + 1), [acc * 100 for acc in history['train_acc']], label='Train Accuracy')
axs[0, 1].plot(range(1, epochs + 1), [acc * 100 for acc in history['test_acc']], label='Test Accuracy')
axs[0, 1].set_title('Global Classification Accuracy Curve')
axs[0, 1].set_xlabel('Epochs')
axs[0, 1].set_ylabel('Accuracy (%)')
axs[0, 1].legend()
axs[0, 1].grid(True)

# 3. Macro Precision Curve
axs[0, 2].plot(range(1, epochs + 1), [p * 100 for p in history['train_precision']], label='Train Precision')
axs[0, 2].plot(range(1, epochs + 1), [p * 100 for p in history['test_precision']], label='Test Precision')
axs[0, 2].set_title('Macro Precision Curve')
axs[0, 2].set_xlabel('Epochs')
axs[0, 2].set_ylabel('Precision (%)')
axs[0, 2].legend()
axs[0, 2].grid(True)

# 4. Macro Recall Curve
axs[1, 0].plot(range(1, epochs + 1), [r * 100 for r in history['train_recall']], label='Train Recall')
axs[1, 0].plot(range(1, epochs + 1), [r * 100 for r in history['test_recall']], label='Test Recall')
axs[1, 0].set_title('Macro Recall Curve')
axs[1, 0].set_xlabel('Epochs')
axs[1, 0].set_ylabel('Recall (%)')
axs[1, 0].legend()
axs[1, 0].grid(True)

# 5. Macro F1-Score Curve (The definitive health metric for balanced classes)
axs[1, 1].plot(range(1, epochs + 1), [f * 100 for f in history['train_f1']], label='Train F1')
axs[1, 1].plot(range(1, epochs + 1), [f * 100 for f in history['test_f1']], label='Test F1')
axs[1, 1].set_title('Macro F1-Score Curve')
axs[1, 1].set_xlabel('Epochs')
axs[1, 1].set_ylabel('F1-Score (%)')
axs[1, 1].legend()
axs[1, 1].grid(True)

# Huber Loss Curve
axs[1, 2].plot(range(1, epochs + 1), history['train_huber_loss'], label='Train Huber Loss')
axs[1, 2].plot(range(1, epochs + 1), history['test_huber_loss'], label='Test Huber Loss')
axs[1, 2].set_title(f'Huber Loss Curve')
axs[1, 2].set_xlabel('Epochs')
axs[1, 2].set_ylabel('Huber Loss')
axs[1, 2].legend()
axs[1, 2].grid(True)

plt.tight_layout()
plt.show()

# %%
model_save_path = '../../data/model/Neural_Network_Model_classification.pkl'
torch.save(model.state_dict(), model_save_path)
print(f"PyTorch weights successfully saved to '{model_save_path}'")
# Out:
# PyTorch weights successfully saved to '../../data/model/Neural_Network_Model_classification.pkl'
